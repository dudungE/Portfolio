# %%
import matplotlib.pyplot as plt

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# %%
sec=pdr.get_data_yahoo('005930.KS',start='2019-05-04')
msft=pdr.get_data_yahoo('MSFT',start='2019-05-04')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
sec.head()
# Out:
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2019-05-07  45250.0  45300.0  44400.0  44850.0  40224.484375  12014907
# 2019-05-08  44300.0  44850.0  44200.0  44250.0  39686.363281  10398754
# 2019-05-09  43900.0  44250.0  42450.0  42450.0  38072.000000  23029718
# 2019-05-10  42600.0  43450.0  42450.0  42900.0  38475.597656  14579512
# 2019-05-13  42500.0  43200.0  42350.0  42650.0  38251.375000   7635079

# %%
msft.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-05-06  126.389999  128.559998  126.110001  128.149994  122.986168
# 2019-05-07  126.459999  127.180000  124.220001  125.519997  120.462151
# 2019-05-08  125.440002  126.370003  124.750000  125.510002  120.452545
# 2019-05-09  124.290001  125.790001  123.570000  125.500000  120.442940
# 2019-05-10  124.910004  127.930000  123.820000  127.129997  122.007263
#
#               Volume
# Date
# 2019-05-06  24239800
# 2019-05-07  36017700
# 2019-05-08  28419000
# 2019-05-09  27235800
# 2019-05-10  30915100

# %%
plt.plot(sec.index, sec.Close, 'b', label='Samsung')
plt.plot(msft.index, msft.Close, 'r--', label='Microsoft')
plt.legend(loc='best');

# %%
# shift?
type(sec['Close'])
sec['Close'].shift(1).head()  #데이터를 n만큼 lag
# Out:
# Date
# 2019-05-07        NaN
# 2019-05-08    44850.0
# 2019-05-09    44250.0
# 2019-05-10    42450.0
# 2019-05-13    42900.0
# Name: Close, dtype: float64

# %%
#shift활용하여 수익률로 표현
sec_dpc=(sec['Close']/sec['Close'].shift(1)-1)*100
sec_dpc.head()
# Out:
# Date
# 2019-05-07         NaN
# 2019-05-08   -1.337793
# 2019-05-09   -4.067797
# 2019-05-10    1.060071
# 2019-05-13   -0.582751
# Name: Close, dtype: float64

# %%
sec_dpc.iloc[0]=0
sec_dpc.head()
# Out:
# Date
# 2019-05-07    0.000000
# 2019-05-08   -1.337793
# 2019-05-09   -4.067797
# 2019-05-10    1.060071
# 2019-05-13   -0.582751
# Name: Close, dtype: float64

# %%
plt.hist(sec_dpc, bins=20)
plt.grid(True)

#x축 : 주가수익률  4~5만원이였는데 코로나 사태 이후 8만원대 이상으로 급증

# %%
sec_dpc.describe()
# Out:
# count    936.000000
# mean       0.048885
# std        1.633577
# min       -6.387665
# 25%       -0.967073
# 50%        0.000000
# 75%        0.859107
# max       10.470588
# Name: Close, dtype: float64

# %%
#일간 변동률의 누적합 ~ 관측시점기준으로 최종 수익률 산출
sec_dpc_cs=sec_dpc.cumsum()
sec_dpc_cs
# Out:
# Date
# 2019-05-07     0.000000
# 2019-05-08    -1.337793
# 2019-05-09    -5.405589
# 2019-05-10    -4.345519
# 2019-05-13    -4.928269
#                 ...
# 2023-02-13    46.176695
# 2023-02-14    46.653642
# 2023-02-15    45.071364
# 2023-02-16    47.482940
# 2023-02-17    45.756095
# Name: Close, Length: 936, dtype: float64

# %%
#Microsoft
msft_dpc = (msft['Close']/msft['Close'].shift(1)-1)*100
msft_dpc.iloc[0] = 0
msft_dpc_cs = msft_dpc.cumsum()
msft_dpc_cs.head()
# Out:
# Date
# 2019-05-06    0.000000
# 2019-05-07   -2.052280
# 2019-05-08   -2.060243
# 2019-05-09   -2.068212
# 2019-05-10   -0.769410
# Name: Close, dtype: float64

# %%
msft_dpc_cs=msft_dpc.cumsum()
msft_dpc_cs
# Out:
# Date
# 2019-05-06     0.000000
# 2019-05-07    -2.052280
# 2019-05-08    -2.060243
# 2019-05-09    -2.068212
# 2019-05-10    -0.769410
#                 ...
# 2023-02-10    91.938313
# 2023-02-13    95.062601
# 2023-02-14    95.375886
# 2023-02-15    94.328744
# 2023-02-16    91.666479
# Name: Close, Length: 955, dtype: float64

# %%
plt.plot(sec.index, sec_dpc_cs, 'b', label='Samsung')
plt.plot(msft.index, msft_dpc_cs, 'r--', label='Microsoft')
plt.legend(loc='best')
plt.xticks(rotation=45)
plt.show;

# %% [markdown]
# # MDD

# %%
kospi = pdr.get_data_yahoo('^KS11', '2004-01-04')

window=252    # 주식 개장일
peak = kospi['Adj Close'].rolling(window, min_periods=1).max()
drawdown = kospi['Adj Close']/peak - 1.0
max_dd = drawdown.rolling(window, min_periods=1).min()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize=(9,7))
plt.subplot(211)
kospi['Close'].plot(label='KOSPI',title='KOSPI MDD',grid=True,legend=True)

plt.subplot(212)
drawdown.plot(c='blue',label='KOSPI DD',grid=True,legend=True)
max_dd.plot(c='red',label='KOSPI MDD',grid=True,legend=True)
plt.show()

# %%
max_dd.min()
max_dd[max_dd==max_dd.min()]
# Out:
# Date
# 2008-10-24   -0.545367
# 2008-10-27   -0.545367
# 2008-10-28   -0.545367
# 2008-10-29   -0.545367
# 2008-10-30   -0.545367
#                 ...
# 2009-10-16   -0.545367
# 2009-10-19   -0.545367
# 2009-10-20   -0.545367
# 2009-10-21   -0.545367
# 2009-10-22   -0.545367
# Name: Adj Close, Length: 252, dtype: float64

# %%
dow = pdr.get_data_yahoo('^DJI', '2000-01-04')
kospi = pdr.get_data_yahoo('^KS11', '2000-01-04')

plt.figure(figsize=(9,5))
plt.plot(dow.index, dow.Close, 'r--', label='dow')
plt.plot(kospi.index, kospi.Close, 'b', label='kospi')
plt.grid(True)
plt.legend(loc='best')
plt.show();
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
d = (dow.Close / dow.Close.loc['2000-01-04'])*100
k = (kospi.Close / kospi.Close.loc['2000-01-04'])*100

plt.figure(figsize=(9,5))
plt.plot(d.index, d, 'r', label='dow')
plt.plot(k.index, k, 'b', label='kospi')
plt.grid(True)
plt.legend(loc='best')
plt.show();

# %%
print('dow :',len(dow)); print('kospi :',len(kospi))
# plt.scatter(dow, kospi, marker='.')
# Out:
# dow : 5818
# kospi : 5705

# %%
import pandas as pd
df = pd.DataFrame({'DOW':dow['Close'], 'KOSPI':kospi['Close']})
df
# Out:
#                      DOW        KOSPI
# Date
# 2000-01-04  10997.929688  1059.040039
# 2000-01-05  11122.650391   986.309998
# 2000-01-06  11253.259766   960.789978
# 2000-01-07  11522.559570   948.650024
# 2000-01-10  11572.200195   987.239990
# ...                  ...          ...
# 2023-02-13  34245.929688  2452.699951
# 2023-02-14  34089.269531  2465.639893
# 2023-02-15  34128.050781  2427.899902
# 2023-02-16  33696.851562  2475.479980
# 2023-02-17           NaN  2451.209961
#
# [5998 rows x 2 columns]

# %%
df=df.fillna(method='bfill')
df=df.fillna(method='ffill')
print(df.tail())
# Out:
#                      DOW        KOSPI
# Date
# 2023-02-13  34245.929688  2452.699951
# 2023-02-14  34089.269531  2465.639893
# 2023-02-15  34128.050781  2427.899902
# 2023-02-16  33696.851562  2475.479980
# 2023-02-17  33696.851562  2451.209961

# %%
plt.figure(figsize=(7,7))
plt.scatter(df['DOW'],df['KOSPI'],marker='.')
plt.xlabel('DOW')
plt.ylabel('KOSPI')
plt.show();

#다우코스피 우상향이유?

# %%
# pip install scipy
from scipy import stats
regr = stats.linregress(df['DOW'],df['KOSPI'])
print(regr)
# Out:
# LinregressResult(slope=0.07068845082419943, intercept=536.8683412754101, rvalue=0.8219289293077818, pvalue=0.0, stderr=0.0006326241783588977, intercept_stderr=11.479425152377619)

# %%
df.corr()
# Out:
#             DOW     KOSPI
# DOW    1.000000  0.821929
# KOSPI  0.821929  1.000000

# %%
r_value = df['DOW'].corr(df['KOSPI'])
r_squared = r_value ** 2
print('결정계수:',r_squared)
# Out:
# 결정계수: 0.6755671648330368

# %%
regr = stats.linregress(df.DOW,df.KOSPI)
regr_line = f'KOSPI = {regr.slope:.2f} * DOW + {regr.intercept:.2f}'

# %%
regr.slope
# Out:
# 0.07068845082419943

# %%
plt.figure(figsize=(7,7))

plt.plot(df.DOW, df.KOSPI, '.')
plt.plot(df.DOW, regr.slope * df.DOW + regr.intercept, 'r')

plt.legend(['DOW x KOSPI', regr_line])
plt.title(f'DOW x KOSPI (R = {regr.rvalue:.2f})')
plt.xlabel('다우')
plt.ylabel('코스피')
plt.show()
# Out:
# C:\Users\jjgus\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jjgus\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50864 (\N{HANGUL SYLLABLE U}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jjgus\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 53076 (\N{HANGUL SYLLABLE KO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jjgus\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jjgus\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54588 (\N{HANGUL SYLLABLE PI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # 미국채 코스피

# %%
tlt = pdr.get_data_yahoo('TLT', '2002-07-30')
kospi = pdr.get_data_yahoo('^KS11', '2002-07-30')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
df = pd.DataFrame({'X':tlt['Close'], 'Y':kospi['Close']})
df = df.fillna(method='bfill')
df = df.fillna(method='ffill')

# %%
regr = stats.linregress(df.X, df.Y)
regr_line = f'Y = {regr.slope:2f}  X + {regr.intercept:2f}'

# %%
plt.figure(figsize=(7, 7))
plt.plot(df.X, df.Y, 'x') 
plt.plot(df.X, regr.slope * df.X + regr.intercept, 'r')

plt.legend(['TLT x KOSPI', regr_line])
plt.title(f'TLT x KOSPI (R = {regr.rvalue:2f})')
plt.xlabel('TLT')
plt.ylabel('KOSPI')
plt.show();

# 미국채금리상승 ~ 국채가격하락, 주식하락

# %% [markdown]
# # 미국채금리

# %%
# 미국채권금리
TNX = pdr.get_data_yahoo('^TNX', '2002-07-30')
TNX['Close'].plot();
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize=(9,7))

#코스피
plt.gca().title.set_text('kospi')
plt.subplot(311)
plt.plot(kospi['Close'])

#미국장기채권가격
plt.subplot(312)
plt.plot(tlt['Close'])

#미국장기채권금리
plt.subplot(313)
plt.plot(TNX['Close'])


plt.show()

# %%
dow2 = pdr.get_data_yahoo('^DJI', '2002-07-30')
dow2 = dow2.fillna(method='bfill')
dow2 = dow2.fillna(method='ffill')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
d = (tlt.Close / tlt.Close.loc['2002-07-30'])*100
k = (kospi.Close / kospi.Close.loc['2002-07-30'])*100
c = (TNX.Close / TNX.Close.loc['2002-07-30'])*100
j = (dow2.Close / dow2.Close.loc['2002-07-30'])*100

plt.figure(figsize=(9,5))
plt.plot(d.index, d, 'r', label='TLT')
plt.plot(k.index, k, 'b', label='KOSPI')
plt.plot(c.index, c, 'g', label='TNX')
plt.plot(j.index, j, 'y', label='DOW')

plt.grid(True)
plt.legend(loc='best')
plt.show();
