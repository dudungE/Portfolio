# %%
import pandas as pd
from scipy import stats
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
import matplotlib.pyplot as plt
# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
ss = pdr.get_data_yahoo('005930.KS',start='2005-01-04')
msft = pdr.get_data_yahoo('MSFT',start='2005-01-04')

dow = pdr.get_data_yahoo('^DJI', '2005-01-04')
kospi = pdr.get_data_yahoo('^KS11', '2005-01-04')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize=(15,10))

plt.subplot(211)
plt.plot(ss.index, ss.Close, 'b', label='Samsung')
plt.plot(msft.index, msft.Close, 'r--', label='Microsoft')
plt.grid(True)
plt.legend(loc='best');

plt.subplot(212)
plt.plot(dow.index, dow.Close, 'r--', label='dow')
plt.plot(kospi.index, kospi.Close, 'b', label='kospi')
plt.grid(True)
plt.legend(loc='best')
            
plt.show();

# %%
kospi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4482 entries, 2005-01-04 to 2023-02-24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       4482 non-null   float64
#  1   High       4482 non-null   float64
#  2   Low        4482 non-null   float64
#  3   Close      4482 non-null   float64
#  4   Adj Close  4482 non-null   float64
#  5   Volume     4482 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 245.1 KB

# %% [markdown]
# # 누적수익률

# %%
ss_ret_daily = ss.pct_change().cumsum()
msft_ret_daily= msft.pct_change().cumsum()
dow_ret_daily = dow.pct_change().cumsum()
kospi_ret_daily= kospi.pct_change().cumsum()

plt.figure(figsize=(15,10))

plt.subplot(211)
plt.plot(ss_ret_daily.index, ss_ret_daily.Close, 'b', label='Samsung')
plt.plot(msft_ret_daily.index, msft_ret_daily.Close, 'r--', label='Microsoft')
plt.grid(True)
plt.legend(loc='best');

plt.subplot(212)
plt.plot(kospi_ret_daily.index, kospi_ret_daily.Close, 'b', label='kospi')
plt.plot(dow_ret_daily.index, dow_ret_daily.Close, 'r--', label='dow')

plt.grid(True)
plt.legend(loc='best')
            
plt.show();

# %% [markdown]
# # 상관관계

# %%
df = pd.DataFrame({'SAMSUNG':ss['Close'], 'MSFT':msft['Close'], 
                   'DOW':dow['Close'], 'KOSPI':kospi['Close']})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4707 entries, 2005-01-04 to 2023-02-24
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SAMSUNG  4505 non-null   float64
#  1   MSFT     4566 non-null   float64
#  2   DOW      4566 non-null   float64
#  3   KOSPI    4482 non-null   float64
# dtypes: float64(4)
# memory usage: 183.9 KB

# %%
df = df.fillna(method='bfill')
df = df.fillna(method='ffill')
df.info() # 결측치 채워주기
print('========================================')
df = df.fillna(method='bfill')
df = df.fillna(method='ffill')
df.info() # 결측치 채워주기
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4707 entries, 2005-01-04 to 2023-02-24
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SAMSUNG  4707 non-null   float64
#  1   MSFT     4707 non-null   float64
#  2   DOW      4707 non-null   float64
#  3   KOSPI    4707 non-null   float64
# dtypes: float64(4)
# memory usage: 183.9 KB
# ========================================
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4707 entries, 2005-01-04 to 2023-02-24
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SAMSUNG  4707 non-null   float64
#  1   MSFT     4707 non-null   float64
#  2   DOW      4707 non-null   float64
#  3   KOSPI    4707 non-null   float64
# dtypes: float64(4)
# memory usage: 183.9 KB

# %%
regr_stock = stats.linregress(df['MSFT'], df['SAMSUNG'])
regr_stock_line = f'Y = {regr_stock.slope:2f}X + {regr_stock.intercept:2f}'
print(regr_stock)

regr_index = stats.linregress(df['DOW'],df['KOSPI'])
regr_index_line = f'Y = {regr_index.slope:2f}X + {regr_index.intercept:2f}'
print(regr_index)
# Out:
# LinregressResult(slope=223.53563303054565, intercept=13692.604027043522, rvalue=0.9136618648021001, pvalue=0.0, stderr=1.449824329624461, intercept_stderr=168.38171237623914)
# LinregressResult(slope=0.05155320757448851, intercept=1028.0590806523564, rvalue=0.8503333990231123, pvalue=0.0, stderr=0.0004651297115271201, intercept_stderr=9.227394817752625)

# %%
plt.figure(figsize=(15,8))

plt.subplot(121)
plt.plot(df.MSFT, df.SAMSUNG, 'x') 
plt.plot(df.MSFT, regr_stock.slope * df.MSFT + regr_stock.intercept, 'r')
plt.legend(['SAMSUNG x MSFT', regr_stock_line])
plt.title(f'SAMSUNG x MSFT (R_sqaured = {regr_stock.rvalue:2f})')
plt.xlabel('SAMSUNG')
plt.ylabel('MSFT')

plt.subplot(122)
plt.plot(df.DOW, df.KOSPI, 'x') 
plt.plot(df.DOW, regr_index.slope * df.DOW + regr_index.intercept, 'r')
plt.legend(['DOW x KOSPI', regr_index_line])
plt.title(f'DOW x KOSPI (R_sqaured = {regr_index.rvalue:2f})')
plt.xlabel('DOW')
plt.ylabel('KOSPI')
plt.show();

# %%
df[['DOW', 'KOSPI']].corr()
# Out:
#             DOW     KOSPI
# DOW    1.000000  0.850333
# KOSPI  0.850333  1.000000

# %%
df.corr()
# Out:
#           SAMSUNG      MSFT       DOW     KOSPI
# SAMSUNG  1.000000  0.913662  0.962602  0.887137
# MSFT     0.913662  1.000000  0.935220  0.760391
# DOW      0.962602  0.935220  1.000000  0.850333
# KOSPI    0.887137  0.760391  0.850333  1.000000

# %% [markdown]
# # 삼성 KOSPI

# %%
df_kor = pd.DataFrame({'KOSPI':kospi['Close'], 'SAMSUNG':ss['Close']})
df_kor.info()
